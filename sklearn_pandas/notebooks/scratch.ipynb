# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(1, '../..')
import sklearn_pandas
from sklearn_pandas.transformers.numeric_transform import EntropyBinning

from importlib import reload
sklearn_pandas.transformers.numeric_transform = reload(sklearn_pandas.transformers.numeric_transform)

from sklearn_pandas.transformers.numeric_transform import EntropyBinning

from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(data=np.c_[iris['data'], iris['target']], columns= iris['feature_names'] + ['target'])
df.columns = df.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
X = df[['sepal_length_cm', 'sepal_width_cm', 'petal_length_cm', 'petal_width_cm']]
y = df['target']

# %%
X.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2

# %%
eb = EntropyBinning()
eb.fit(X, y)
# Out:
# sepal_length_cm
#      x    y    w
# 0  5.1  0.0  1.0
# 1  4.9  0.0  1.0
# 2  4.7  0.0  1.0
# 3  4.6  0.0  1.0
# 4  5.0  0.0  1.0
#        x    y    w
# 145  6.7  2.0  1.0
# 146  6.3  2.0  1.0
# 147  6.5  2.0  1.0
# 148  6.2  2.0  1.0
# 149  5.9  2.0  1.0
# 150 150 150
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length_cm, dtype: float64
#                                   x         y        w
# q
# Missing                         NaN  0.000000   0.0001
# (4.2989999999999995, 4.4]  4.375000  0.000000   4.0000
# (4.4, 4.6]                 4.580000  0.000000   5.0000
# (4.694, 4.8]               4.771429  0.000000   7.0000
# (4.8, 4.9]                 4.900000  0.500000   6.0000
# (4.9, 5.0]                 5.000000  0.200000  10.0000
# (5.0, 5.1]                 5.100000  0.111111   9.0000
# (5.1, 5.2]                 5.200000  0.250000   4.0000
# (5.27, 5.4]                5.385714  0.142857   7.0000
# (5.4, 5.5]                 5.500000  0.714286   7.0000
# (5.5, 5.6]                 5.600000  1.166667   6.0000
# (5.6, 5.7]                 5.700000  0.875000   8.0000
# (5.7, 5.8]                 5.800000  1.285714   7.0000
# (5.8, 5.9]                 5.900000  1.333333   3.0000
# (5.9, 6.0]                 6.000000  1.333333   6.0000
# (6.0, 6.1]                 6.100000  1.333333   6.0000
# (6.1, 6.2]                 6.200000  1.500000   4.0000
# (6.234, 6.3]               6.300000  1.666667   9.0000
# (6.328, 6.4]               6.400000  1.714286   7.0000
# (6.4, 6.5]                 6.500000  1.800000   5.0000
# (6.52, 6.7]                6.680000  1.500000  10.0000
# (6.7, 6.8]                 6.800000  1.666667   3.0000
# (6.8, 6.9]                 6.900000  1.750000   4.0000
# (6.9, 7.008]               7.000000  1.000000   1.0000
# (7.008, 7.2]               7.175000  2.000000   4.0000
# (7.2, 7.408]               7.350000  2.000000   2.0000
# (7.408, 7.7]               7.680000  2.000000   5.0000
# (7.7, 7.9]                 7.900000  2.000000   1.0000
# sepal_width_cm
#      x    y    w
# 0  3.5  0.0  1.0
# 1  3.0  0.0  1.0
# 2  3.2  0.0  1.0
# 3  3.1  0.0  1.0
# 4  3.6  0.0  1.0
#        x    y    w
# 145  3.0  2.0  1.0
# 146  2.5  2.0  1.0
# 147  3.0  2.0  1.0
# 148  3.4  2.0  1.0
# 149  3.0  2.0  1.0
# 150 150 150
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width_cm, dtype: float64
#                        x         y        w
# q
# Missing              NaN  0.000000   0.0001
# (1.999, 2.2]    2.150000  1.250000   4.0000
# (2.2, 2.3]      2.300000  0.750000   4.0000
# (2.3, 2.4]      2.400000  1.000000   3.0000
# (2.4, 2.5]      2.500000  1.500000   8.0000
# (2.5, 2.6]      2.600000  1.400000   5.0000
# (2.684, 2.7]    2.700000  1.444444   9.0000
# (2.778, 2.8]    2.800000  1.571429  14.0000
# (2.8, 2.9]      2.900000  1.100000  10.0000
# (2.962, 3.0]    3.000000  1.230769  26.0000
# (3.0, 3.1]      3.100000  1.000000  11.0000
# (3.1, 3.2]      3.200000  1.000000  13.0000
# (3.2, 3.3]      3.300000  1.166667   6.0000
# (3.3, 3.4]      3.400000  0.416667  12.0000
# (3.4, 3.5]      3.500000  0.000000   6.0000
# (3.5, 3.6]      3.600000  0.500000   4.0000
# (3.61, 3.708]   3.700000  0.000000   3.0000
# (3.708, 3.8]    3.800000  0.666667   6.0000
# (3.804, 4.002]  3.933333  0.000000   3.0000
# (4.002, 4.4]    4.233333  0.000000   3.0000
# petal_length_cm
#      x    y    w
# 0  1.4  0.0  1.0
# 1  1.4  0.0  1.0
# 2  1.3  0.0  1.0
# 3  1.5  0.0  1.0
# 4  1.4  0.0  1.0
#        x    y    w
# 145  5.2  2.0  1.0
# 146  5.0  2.0  1.0
# 147  5.2  2.0  1.0
# 148  5.4  2.0  1.0
# 149  5.1  2.0  1.0
# 150 150 150
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: petal_length_cm, dtype: float64
#                        x         y        w
# q
# Missing              NaN  0.000000   0.0001
# (0.999, 1.2]    1.125000  0.000000   4.0000
# (1.2, 1.3]      1.300000  0.000000   7.0000
# (1.3, 1.4]      1.400000  0.000000  13.0000
# (1.484, 1.5]    1.500000  0.000000  13.0000
# (1.5, 1.6]      1.600000  0.000000   7.0000
# (1.6, 1.7]      1.700000  0.000000   4.0000
# (1.836, 3.198]  2.266667  0.333333   3.0000
# (3.198, 3.5]    3.400000  1.000000   4.0000
# (3.5, 3.762]    3.650000  1.000000   2.0000
# (3.762, 3.9]    3.875000  1.000000   4.0000
# (3.9, 4.0]      4.000000  1.000000   5.0000
# (4.056, 4.154]  4.100000  1.000000   3.0000
# (4.154, 4.2]    4.200000  1.000000   4.0000
# (4.2, 4.35]     4.300000  1.000000   2.0000
# (4.35, 4.4]     4.400000  1.000000   4.0000
# (4.4, 4.5]      4.500000  1.125000   8.0000
# (4.542, 4.64]   4.600000  1.000000   3.0000
# (4.64, 4.7]     4.700000  1.000000   5.0000
# (4.7, 4.8]      4.800000  1.500000   4.0000
# (4.834, 4.9]    4.900000  1.600000   5.0000
# (4.9, 5.0]      5.000000  1.750000   4.0000
# (5.028, 5.1]    5.100000  1.875000   8.0000
# (5.1, 5.2]      5.200000  2.000000   2.0000
# (5.2, 5.32]     5.300000  2.000000   2.0000
# (5.32, 5.5]     5.460000  2.000000   5.0000
# (5.5, 5.6]      5.600000  2.000000   6.0000
# (5.6, 5.7]      5.700000  2.000000   3.0000
# (5.7, 5.8]      5.800000  2.000000   3.0000
# (5.8, 5.9]      5.900000  2.000000   2.0000
# (5.9, 6.006]    6.000000  2.000000   2.0000
# (6.006, 6.108]  6.100000  2.000000   3.0000
# (6.108, 6.602]  6.433333  2.000000   3.0000
# (6.602, 6.9]    6.766667  2.000000   3.0000
# petal_width_cm
#      x    y    w
# 0  0.2  0.0  1.0
# 1  0.2  0.0  1.0
# 2  0.2  0.0  1.0
# 3  0.2  0.0  1.0
# 4  0.2  0.0  1.0
#        x    y    w
# 145  2.3  2.0  1.0
# 146  1.9  2.0  1.0
# 147  2.0  2.0  1.0
# 148  2.3  2.0  1.0
# 149  1.8  2.0  1.0
# 150 150 150
# 0    0.2
# 1    0.2
# 2    0.2
# 3    0.2
# 4    0.2
# Name: petal_width_cm, dtype: float64
#                        x         y        w
# q
# Missing              NaN  0.000000   0.0001
# (0.099, 0.2]    0.185294  0.000000  34.0000
# (0.2, 0.3]      0.300000  0.000000   7.0000
# (0.3, 0.4]      0.400000  0.000000   7.0000
# (0.468, 1.0]    0.900000  0.777778   9.0000
# (1.062, 1.16]   1.100000  1.000000   3.0000
# (1.16, 1.2]     1.200000  1.000000   5.0000
# (1.2, 1.3]      1.300000  1.000000  13.0000
# (1.348, 1.4]    1.400000  1.125000   8.0000
# (1.4, 1.5]      1.500000  1.166667  12.0000
# (1.5, 1.6]      1.600000  1.250000   4.0000
# (1.632, 1.8]    1.785714  1.857143  14.0000
# (1.8, 1.9]      1.900000  2.000000   5.0000
# (1.9, 2.0]      2.000000  2.000000   6.0000
# (2.0, 2.1]      2.100000  2.000000   6.0000
# (2.1, 2.2]      2.200000  2.000000   3.0000
# (2.2, 2.3]      2.300000  2.000000   8.0000
# (2.304, 2.402]  2.400000  2.000000   3.0000
# (2.402, 2.5]    2.500000  2.000000   3.0000
# EntropyBinning(max_bins=10, max_cuts=10, method='entropy', min_gain=0.01,
#         min_pop=0.1, nhist=50, noise_penalty=0.0, prefix='',
#         suffix='__binned')
